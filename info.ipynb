# %%
import pandas as pd
df = pd.read_csv("../newone.csv")

# %%
df
# Out:
#          Unnamed: 0.1  Unnamed: 0  \
# 0                   0      471475
# 1                   1      471024
# 2                   2      471232
# 3                   3     2048313
# 4                   4      470799
# ...               ...         ...
# 1499846       1499846      184764
# 1499847       1499847      183734
# 1499848       1499848      184836
# 1499849       1499849      184541
# 1499850       1499850      185677
#
#                                                      title  \
# 0        Dapper has a new home. NOT CLICKBAIT…Please wa...
# 1        Dapper has a new home. NOT CLICKBAIT…Please wa...
# 2        Dapper has a new home. NOT CLICKBAIT…Please wa...
# 3        Dapper has a new home. NOT CLICKBAIT…Please wa...
# 4        Dapper has a new home. NOT CLICKBAIT…Please wa...
# ...                                                    ...
# 1499846  MINHA PRIMEIRA COMPRINHA PARA CASA NOVA! CARRO...
# 1499847  TOUR! DEPOIS DE TANTA HUMILHAÇÃO! CONSEGUIMOS!...
# ...
